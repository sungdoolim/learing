# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
hello=tf.constant('hello world')
sess=tf.Session()
print(sess.run(hello))
# Out:
# b'hello world'

# %%
# 선형!------------------------------------------------------------------------------------
xData=[1,2,3,4,5,6,7]
yData=[25,55,75,110,128,155,180]
W=tf.Variable(tf.random_uniform([1],-100,100))
b=tf.Variable(tf.random_uniform([1],-100,100))
X=tf.placeholder(tf.float32)
Y=tf.placeholder(tf.float32)
H=W*X+b

# %%
cost=tf.reduce_mean(tf.square(H-Y))
a=tf.Variable(0.01)
optimizer=tf.train.GradientDescentOptimizer(a)
train=optimizer.minimize(cost)

# %%
init=tf.global_variables_initializer()
sess=tf.Session()
sess.run(init)
for i in range(5001):
    sess.run(train,feed_dict={X:xData,Y: yData})
    if i%500 ==0:
        print(i, sess.run(cost,feed_dict={X:xData,Y:yData}),sess.run(W),sess.run(b))
        
print(sess.run(H,feed_dict={X:[8]}))
# Out:
# 0 19263.479 [4.6184883] [-46.711426]
# 500 16.18938 [26.883923] [-4.7171135]
# 1000 8.793117 [25.823706] [0.5330202]
# 1500 8.636055 [25.66921] [1.2980696]
# 2000 8.632727 [25.646696] [1.4095535]
# 2500 8.632653 [25.643417] [1.4257989]
# 3000 8.632651 [25.64294] [1.4281591]
# 3500 8.63265 [25.642876] [1.4284877]
# 4000 8.632652 [25.64287] [1.4285164]
# 4500 8.632652 [25.64287] [1.4285164]
# 5000 8.632652 [25.64287] [1.4285164]
# [206.57147]

# %%
#-----------------------------------------------함수 만들기
# 기본적으로 tf.add(a,b)/ multiply / truediv / mod / abs / subtact / 
# tf.sigh(a) a 의 부호를 판별 1 0 -1
# tf.square(a)  제곱
# tf.pow(a,4)  a^4
# tf.maximum / tf.minimum(a,b)
# tf.exp(a) /tf.sin(a)/ tf.log(a)

# %%
#------------------------------------------------k-means datamining
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
 df=pd.DataFrame(columns=['x','y'])
df.loc[0] = [2,3]
df.loc[1] = [2,11]
df.loc[2] = [2,18]
df.loc[3] = [4,5]
df.loc[4] = [4,7]
df.loc[5] = [5,3]
df.loc[6] = [5,15]
df.loc[7] = [6,6]
df.loc[8] = [6,8]
df.loc[9] = [6,9]
df.loc[10] = [7,2]
df.loc[11] = [7,4]
df.loc[12] = [7,5]
df.loc[13] = [7,17]
df.loc[14] = [7,18]
df.loc[15] = [8,5]
df.loc[16] = [8,4]
df.loc[17] = [9,10]
df.loc[18] = [9,11]
df.loc[19] = [9,15]
df.loc[20] = [9,19]
df.loc[21] = [10,5]
df.loc[22] = [10,8]
df.loc[23] = [10,18]
df.loc[24] = [12,6]
df.loc[25] = [13,5]
df.loc[26] = [14,11]
df.loc[27] = [15,6]
df.loc[28] = [15,18]
df.loc[29] = [18,12]

# %%
df.head(30)
# Out:
#      x   y
# 0    2   3
# 1    2  11
# 2    2  18
# 3    4   5
# 4    4   7
# 5    5   3
# 6    5  15
# 7    6   6
# 8    6   8
# 9    6   9
# 10   7   2
# 11   7   4
# 12   7   5
# 13   7  17
# 14   7  18
# 15   8   5
# 16   8   4
# 17   9  10
# 18   9  11
# 19   9  15
# 20   9  19
# 21  10   5
# 22  10   8
# 23  10  18
# 24  12   6
# 25  13   5
# 26  14  11
# 27  15   6
# 28  15  18
# 29  18  12

# %%
sb.lmplot('x','y',data=df,fit_reg=False,scatter_kws={"s":100})

# %%
sb.lmplot('x','y',data=df,fit_reg=False,scatter_kws={"s":100})
plt.title('K-means Example')
plt.xlabel('xxx')
plt.ylabel('yyy')
# Out:
# Text(0.29999999999999716, 0.5, 'yyy')

# %%
points=df.values
kmeans=KMeans(n_clusters=4).fit(points)
kmeans.cluster_centers_
# 수행 완료 .. 결과는 그 중심값이 나오는 것임 4개!
# Out:
# array([[ 5.53846154,  5.53846154],
#        [11.5       ,  7.75      ],
#        [16.5       , 15.        ],
#        [ 7.        , 17.14285714]])

# %%
kmeans.labels_
# Out:
# array([0, 0, 3, 0, 0, 0, 3, 0, 0, 0, 0, 0, 0, 3, 3, 0, 0, 1, 1, 3, 3, 1,
#        1, 3, 1, 1, 1, 1, 2, 2])

# %%
df['cluster']=kmeans.labels_
df.head(30)
# Out:
#      x   y  cluster
# 0    2   3        0
# 1    2  11        0
# 2    2  18        3
# 3    4   5        0
# 4    4   7        0
# 5    5   3        0
# 6    5  15        3
# 7    6   6        0
# 8    6   8        0
# 9    6   9        0
# 10   7   2        0
# 11   7   4        0
# 12   7   5        0
# 13   7  17        3
# 14   7  18        3
# 15   8   5        0
# 16   8   4        0
# 17   9  10        1
# 18   9  11        1
# 19   9  15        3
# 20   9  19        3
# 21  10   5        1
# 22  10   8        1
# 23  10  18        3
# 24  12   6        1
# 25  13   5        1
# 26  14  11        1
# 27  15   6        1
# 28  15  18        2
# 29  18  12        2

# %%
sb.lmplot('x','y',data=df,fit_reg=False,scatter_kws={"s":150},hue="cluster")

# %%
#---------------------------------------폴더내에 pdata로 학습 시키기
import tensorflow.compat.v1 as tf
import numpy as np
from pandas.io.parsers import read_csv

model=tf.global_variables_initializer()
data=read_csv('pdata.csv',sep=',')   # , 으로 분류하기 
xy=np.array(data,dtype=np.float32)
print(xy)
# Out:
# [[ 2.0100100e+07 -4.9000001e+00 -1.1000000e+01  8.9999998e-01
#    0.0000000e+00  2.1230000e+03]
#  [ 2.0100102e+07 -3.0999999e+00 -5.5000000e+00  5.5000000e+00
#    8.0000001e-01  2.1230000e+03]
#  [ 2.0100104e+07 -2.9000001e+00 -6.9000001e+00  1.4000000e+00
#    0.0000000e+00  2.1230000e+03]
#  ...
#  [ 2.0171228e+07  2.9000001e+00 -2.0999999e+00  8.0000000e+00
#    0.0000000e+00  2.9010000e+03]
#  [ 2.0171230e+07  2.9000001e+00 -1.6000000e+00  7.0999999e+00
#    6.0000002e-01  2.9010000e+03]
#  [ 2.0171232e+07  2.0999999e+00 -2.0000000e+00  5.8000002e+00
#    4.0000001e-01  2.9010000e+03]]

# %%
#pdata 의 형식은 year,avgTemp,minTemp,maxTemp,rainFall,avgPrice
#20100101,-4.9,-11,0.9,0,2123
#20100102,-3.1,-5.5,5.5,0.8,2123
#요런식....
x_data=xy[:,1:-1]
y_data=xy[:,[-1]]

# %%
X=tf.placeholder(tf.float32,shape=[None,4])
Y=tf.placeholder(tf.float32,shape=[None,1])
W=tf.Variable(tf.random_normal([4,1]),name="weight")
b=tf.Variable(tf.random_normal([1]),name="bias")

# %%
hypothesis=tf.matmul(X,W)+b
cost=tf.reduce_mean(tf.square(hypothesis-Y))
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train=optimizer.minimize(cost)

# %%
sess=tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(100001):

    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})

    if step % 500 == 0:

        print("#", step, " 손실 비용: ", cost_)

        print("- 배추 가격: ", hypo_[0])
# Out:
# # 0  손실 비용:  12788048.0
# - 배추 가격:  [-4.9075704]
# # 500  손실 비용:  4207486.5
# - 배추 가격:  [-287.93268]
# # 1000  손실 비용:  3798039.2
# - 배추 가격:  [23.116459]
# # 1500  손실 비용:  3478180.0
# - 배추 가격:  [306.5524]
# # 2000  손실 비용:  3226568.8
# - 배추 가격:  [558.3794]
# # 2500  손실 비용:  3028179.0
# - 배추 가격:  [782.11475]
# # 3000  손실 비용:  2871508.5
# - 배추 가격:  [980.94666]
# # 3500  손실 비용:  2747656.0
# - 배추 가격:  [1157.6842]
# # 4000  손실 비용:  2649677.8
# - 배추 가격:  [1314.8103]
# # 4500  손실 비용:  2572125.8
# - 배추 가격:  [1454.5205]
# # 5000  손실 비용:  2510715.5
# - 배추 가격:  [1578.7588]
# # 5500  손실 비용:  2462065.8
# - 배추 가격:  [1689.2483]
# # 6000  손실 비용:  2423511.5
# - 배추 가격:  [1787.5184]
# # 6500  손실 비용:  2392940.5
# - 배추 가격:  [1874.9263]
# # 7000  손실 비용:  2368688.2
# - 배추 가격:  [1952.6752]
# # 7500  손실 비용:  2349435.2
# - 배추 가격:  [2021.8363]
# # 8000  손실 비용:  2334138.8
# - 배추 가격:  [2083.359]
# # 8500  손실 비용:  2321973.0
# - 배추 가격:  [2138.089]
# # 9000  손실 비용:  2312284.5
# - 배추 가격:  [2186.7766]
# # 9500  손실 비용:  2304557.5
# - 배추 가격:  [2230.092]
# # 10000  손실 비용:  2298383.5
# - 배추 가격:  [2268.6267]
# # 10500  손실 비용:  2293436.2
# - 배추 가격:  [2302.9092]
# # 11000  손실 비용:  2289462.8
# - 배추 가격:  [2333.4102]
# # 11500  손실 비용:  2286256.8
# - 배추 가격:  [2360.5474]
# # 12000  손실 비용:  2283662.0
# - 배추 가격:  [2384.6917]
# # 12500  손실 비용:  2281547.8
# - 배추 가격:  [2406.1729]
# # 13000  손실 비용:  2279815.2
# - 배추 가격:  [2425.2861]
# # 13500  손실 비용:  2278385.0
# - 배추 가격:  [2442.2922]
# # 14000  손실 비용:  2277194.0
# - 배추 가격:  [2457.4248]
# # 14500  손실 비용:  2276192.2
# - 배추 가격:  [2470.8887]
# # 15000  손실 비용:  2275339.8
# - 배추 가격:  [2482.8699]
# # 15500  손실 비용:  2274606.5
# - 배추 가격:  [2493.5312]
# # 16000  손실 비용:  2273966.5
# - 배추 가격:  [2503.0183]
# # 16500  손실 비용:  2273401.2
# - 배추 가격:  [2583.095]
# # 80000  손실 비용:  2237911.0
# - 배추 가격:  [2583.1064]
# # 80500  손실 비용:  2237651.2
# - 배추 가격:  [2583.118]
# # 81000  손실 비용:  2237392.2
# - 배추 가격:  [2583.1292]
# # 81500  손실 비용:  2237133.5
# - 배추 가격:  [2583.1375]
# # 82000  손실 비용:  2236875.2
# - 배추 가격:  [2583.1436]
# # 82500  손실 비용:  2236616.0
# - 배추 가격:  [2583.1497]
# # 83000  손실 비용:  2236358.0
# - 배추 가격:  [2583.1558]
# # 83500  손실 비용:  2236100.5
# - 배추 가격:  [2583.1619]
# # 84000  손실 비용:  2235841.5
# - 배추 가격:  [2583.168]
# # 84500  손실 비용:  2235583.5
# - 배추 가격:  [2583.1743]
# # 85000  손실 비용:  2235325.5
# - 배추 가격:  [2583.199]
# # 85500  손실 비용:  2235066.8
# - 배추 가격:  [2583.2332]
# # 86000  손실 비용:  2234810.2
# - 배추 가격:  [2583.2678]
# # 86500  손실 비용:  2234552.8
# - 배추 가격:  [2583.3022]
# # 87000  손실 비용:  2234295.0
# - 배추 가격:  [2583.3364]
# # 87500  손실 비용:  2234037.2
# - 배추 가격:  [2583.371]
# # 88000  손실 비용:  2233780.2
# - 배추 가격:  [2583.4062]
# # 88500  손실 비용:  2233523.8
# - 배추 가격:  [2583.4402]
# # 89000  손실 비용:  2233268.2
# - 배추 가격:  [2583.4736]
# # 89500  손실 비용:  2233013.2
# - 배추 가격:  [2583.5078]
# # 90000  손실 비용:  2232760.5
# - 배추 가격:  [2583.542]
# # 90500  손실 비용:  2232506.0
# - 배추 가격:  [2583.5764]
# # 91000  손실 비용:  2232251.8
# - 배추 가격:  [2583.61]
# # 91500  손실 비용:  2231997.2
# - 배추 가격:  [2583.6445]
# # 92000  손실 비용:  2231743.2
# - 배추 가격:  [2583.6782]
# # 92500  손실 비용:  2231490.0
# - 배추 가격:  [2583.7126]
# # 93000  손실 비용:  2231236.5
# - 배추 가격:  [2583.7463]
# # 93500  손실 비용:  2230982.5
# - 배추 가격:  [2583.7812]
# # 94000  손실 비용:  2230729.2
# - 배추 가격:  [2583.8157]
# # 94500  손실 비용:  2230476.2
# - 배추 가격:  [2583.8503]
# # 95000  손실 비용:  2230223.8
# - 배추 가격:  [2583.8845]
# # 95500  손실 비용:  2229970.5
# - 배추 가격:  [2583.9192]
# # 96000  손실 비용:  2229718.0
# - 배추 가격:  [2583.9536]
# # 96500  손실 비용:  2229463.8
# - 배추 가격:  [2583.988]
# # 97000  손실 비용:  2229211.8
# - 배추 가격:  [2584.0234]
# # 97500  손실 비용:  2228959.2
# - 배추 가격:  [2584.058]
# # 98000  손실 비용:  2228707.0
# - 배추 가격:  [2584.093]
# # 98500  손실 비용:  2228454.8
# - 배추 가격:  [2584.1282]
# # 99000  손실 비용:  2228202.8
# - 배추 가격:  [2584.1628]
# # 99500  손실 비용:  2227950.2
# - 배추 가격:  [2584.1982]
# # 100000  손실 비용:  2227697.8
# - 배추 가격:  [2584.2327]

# %%
saver=tf.train.Saver()
save_path=saver.save(sess,"./saved.cpkt")
#     checkpoint / cpkt.data / cpkt.meta/ cpkt.index 가 생성됨

# %%
#-----------------모델을 활용하기
import tensorflow.compat.v1 as tf
import numpy as np
X=tf.placeholder(tf.float32,shape=[None,4])
Y=tf.placeholder(tf.float32,shape=[None,1])
W=tf.Variable(tf.random_normal([4,1]),name="weight")
b=tf.Variable(tf.random_normal([1]),name="bias")
hypothesis=tf.matmul(X,W)+b

# %%
saver=tf.train.Saver()
model=tf.global_variables_initializer()

# %%
#avg_temp=float(input('평균'))   밑 콘솔에 입력창이 뜨게됨
avg_temp = float(input('평균 온도: '))

min_temp = float(input('최저 온도: '))

max_temp = float(input('최고 온도: '))

rain_fall = float(input('강수량: '))
# Out:
# 평균 온도: 15
# 최저 온도: 15
# 최고 온도: 15
# 강수량: 15

# %%
sess=tf.Session()
sess.run(tf.global_variables_initializer())

# %%
save_path="./saved.cpkt"
saver.restore(sess,"saved.cpkt")
# Out:
# INFO:tensorflow:Restoring parameters from saved.cpkt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1366     try:
# -> 1367       return fn(*args)
#    1368     except errors.OpError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1351       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1352                                       target_list, run_metadata)
#    1353
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1444                                             fetch_list, target_list,
# -> 1445                                             run_metadata)
#    1446
#
# NotFoundError: Key bias_26 not found in checkpoint
# 	 [[{{node save_16/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py in restore(self, sess, save_path)
#    1289         sess.run(self.saver_def.restore_op_name,
# -> 1290                  {self.saver_def.filename_tensor_name: save_path})
#    1291     except errors.NotFoundError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     959       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 960                          run_metadata_ptr)
#     961       if run_metadata:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1182       results = self._do_run(handle, final_targets, final_fetches,
# -> 1183                              feed_dict_tensor, options, run_metadata)
#    1184     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1360       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1361                            run_metadata)
#    1362     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1385                     'disable_meta_optimizer = True')
# -> 1386       raise type(e)(node_def, op, message)
#    1387
#
# NotFoundError: Key bias_26 not found in checkpoint
# 	 [[node save_16/RestoreV2 (defined at <ipython-input-242-9d2779c996fd>:1) ]]
#
# Original stack trace for 'save_16/RestoreV2':
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-242-9d2779c996fd>", line 1, in <module>
#     saver=tf.train.Saver()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 828, in __init__
#     self.build()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_io_ops.py", line 1505, in restore_v2
#     name=name)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3322, in _create_op_internal
#     op_def=op_def)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1756, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      69     return CheckpointReader.CheckpointReader_GetTensor(
# ---> 70         self, compat.as_bytes(tensor_str))
#      71   # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#
# RuntimeError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py in restore(self, sess, save_path)
#    1299       try:
# -> 1300         names_to_keys = object_graph_key_mapping(save_path)
#    1301       except errors.NotFoundError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py in object_graph_key_mapping(checkpoint_path)
#    1617   reader = py_checkpoint_reader.NewCheckpointReader(checkpoint_path)
# -> 1618   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1619   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      73   except RuntimeError as e:
# ---> 74     error_translator(e)
#      75
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\py_checkpoint_reader.py in error_translator(e)
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-253-4a684fe125be> in <module>
#       1 save_path="./saved.cpkt"
# ----> 2 saver.restore(sess,"saved.cpkt")
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py in restore(self, sess, save_path)
#    1304         # a helpful message (b/110263146)
#    1305         raise _wrap_restore_error_with_msg(
# -> 1306             err, "a Variable name or other graph key that is missing")
#    1307
#    1308       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key bias_26 not found in checkpoint
# 	 [[node save_16/RestoreV2 (defined at <ipython-input-242-9d2779c996fd>:1) ]]
#
# Original stack trace for 'save_16/RestoreV2':
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-242-9d2779c996fd>", line 1, in <module>
#     saver=tf.train.Saver()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 828, in __init__
#     self.build()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_io_ops.py", line 1505, in restore_v2
#     name=name)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3322, in _create_op_internal
#     op_def=op_def)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1756, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
data=((avg_temp,min_temp,max_temp,rain_fall), )
arr=np.array(data,dtype=np.float32)
x_data=arr[0:4]
dict=sess.run(hypothesis,feed_dict={X:x_data})

# %%
print(dict[0])
# Out:
# [-22.800022]
